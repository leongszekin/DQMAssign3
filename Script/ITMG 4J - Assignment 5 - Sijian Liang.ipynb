# %% [markdown]
# # Assignment 5

# %%
import pandas as pd
import numpy as np

# Load your original heart attack dataset
heart_attack= pd.read_csv("../data/heart_attack_risk_dataset.csv")

# Load the new obesity dataset
obesity= pd.read_csv("../data/Obesity prediction.csv")

# %%
heart_attack.head(10)
# Out:
#    Age  Gender  Smoking  Alcohol_Consumption Physical_Activity_Level    BMI  \
# 0   69  Female        1                    0                Moderate  34.61
# 1   32    Male        0                    0                Moderate  22.75
# 2   89    Male        0                    1                Moderate  35.32
# 3   78    Male        0                    1                Moderate  18.23
# 4   38  Female        1                    0                Moderate  19.82
# 5   41    Male        0                    1                Moderate  36.11
# 6   20    Male        1                    0                     Low  15.12
# 7   39  Female        0                    0                Moderate  20.78
# 8   70    Male        0                    1                    High  29.20
# 9   19  Female        0                    0                    High  35.54
#
#    Diabetes  Hypertension  Cholesterol_Level  Resting_BP  Heart_Rate  \
# ...

# %%
heart_attack.dtypes
# Out:
# Age                          int64
# Gender                      object
# Smoking                      int64
# Alcohol_Consumption          int64
# Physical_Activity_Level     object
# BMI                        float64
# Diabetes                     int64
# Hypertension                 int64
# Cholesterol_Level          float64
# Resting_BP                   int64
# Heart_Rate                   int64
# Family_History               int64
# Stress_Level                object
# Chest_Pain_Type             object
# Thalassemia                 object
# Fasting_Blood_Sugar          int64
# ECG_Results                 object
# Exercise_Induced_Angina      int64
# Max_Heart_Rate_Achieved      int64
# Heart_Attack_Risk           object
# dtype: object

# %%
heart_attack.describe()
# Out:
#                 Age       Smoking  Alcohol_Consumption           BMI  \
# count  50000.000000  50000.000000         50000.000000  50000.000000
# mean      53.398700      0.298420             0.401980     27.519357
# std       20.799006      0.457569             0.490303      7.225176
# min       18.000000      0.000000             0.000000     15.000000
# 25%       35.000000      0.000000             0.000000     21.270000
# 50%       53.000000      0.000000             0.000000     27.540000
# 75%       71.000000      1.000000             1.000000     33.770000
# max       89.000000      1.000000             1.000000     40.000000
#
#            Diabetes  Hypertension  Cholesterol_Level    Resting_BP  \
# count  50000.000000   50000.00000       50000.000000  50000.000000
# mean       0.198840       0.29738         225.036444    134.434100
# std        0.399131       0.45711          43.317373     25.907961
# min        0.000000       0.00000         150.000000     90.000000
# ...

# %%
obesity.head(10)
# Out:
#    Gender   Age  Height  Weight Family_History FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
# 5    Male  29.0    1.62    53.0             no  yes   2.0  3.0  Sometimes
# 6  Female  23.0    1.50    55.0            yes  yes   3.0  3.0  Sometimes
# 7    Male  22.0    1.64    53.0             no   no   2.0  3.0  Sometimes
# 8    Male  24.0    1.78    64.0            yes  yes   3.0  3.0  Sometimes
# 9    Male  22.0    1.72    68.0            yes  yes   2.0  3.0  Sometimes
#
#   Smoking  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0      no   2.0   no  0.0  1.0          no  Public_Transportation
# ...

# %%
obesity.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     23.972525     1.701677    86.586058     2.419043     2.685628
# std       6.308664     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.000000     1.630000    65.473343     2.000000     2.658738
# 50%      22.000000     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
obesity.dtypes
# Out:
# Gender             object
# Age               float64
# Height            float64
# Weight            float64
# Family_History     object
# FAVC               object
# FCVC              float64
# NCP               float64
# CAEC               object
# Smoking            object
# CH2O              float64
# SCC                object
# FAF               float64
# TUE               float64
# CALC               object
# MTRANS             object
# Obesity            object
# dtype: object

# %%
# Use the pandas.DataFrame.astype(<type>) function to manipulate column dtypes.
# https://stackoverflow.com/questions/21291259/convert-floats-to-ints-in-pandas

obesity['Age'] = obesity['Age'].astype(int)

# %%
obesity.dtypes
# Out:
# Gender             object
# Age                 int32
# Height            float64
# Weight            float64
# Family_History     object
# FAVC               object
# FCVC              float64
# NCP               float64
# CAEC               object
# Smoking            object
# CH2O              float64
# SCC                object
# FAF               float64
# TUE               float64
# CALC               object
# MTRANS             object
# Obesity            object
# dtype: object

# %%
# Merge the datasets on Age and Gender
merged_df = heart_attack.merge(obesity, on=["Age","Gender"], how="inner")  

# Display the first few rows of the merged dataset
merged_df.head(50)
# Out:
#     Age  Gender  Smoking_x  Alcohol_Consumption Physical_Activity_Level  \
# 0    32    Male          0                    0                Moderate
# 1    32    Male          0                    0                Moderate
# 2    32    Male          0                    0                Moderate
# 3    32    Male          0                    0                Moderate
# 4    32    Male          0                    0                Moderate
# 5    32    Male          0                    0                Moderate
# 6    32    Male          0                    0                Moderate
# 7    32    Male          0                    0                Moderate
# 8    32    Male          0                    0                Moderate
# 9    32    Male          0                    0                Moderate
# 10   32    Male          0                    0                Moderate
# 11   38  Female          1                    0                Moderate
# ...

# %%
merged_df.describe()
# Out:
#                  Age      Smoking_x  Alcohol_Consumption            BMI  \
# count  699071.000000  699071.000000        699071.000000  699071.000000
# mean       24.394757       0.307223             0.401284      27.403755
# std         6.243142       0.461343             0.490159       7.223686
# min        18.000000       0.000000             0.000000      15.000000
# 25%        20.000000       0.000000             0.000000      21.060000
# 50%        23.000000       0.000000             0.000000      27.330000
# 75%        26.000000       1.000000             1.000000      33.610000
# max        61.000000       1.000000             1.000000      40.000000
#
#             Diabetes   Hypertension  Cholesterol_Level     Resting_BP  \
# count  699071.000000  699071.000000      699071.000000  699071.000000
# mean        0.198372       0.298167         224.811216     134.560438
# std         0.398774       0.457454          43.500194      25.744273
# ...

# %%
merged_df.isna().sum().sum()
# Out:
# 0
