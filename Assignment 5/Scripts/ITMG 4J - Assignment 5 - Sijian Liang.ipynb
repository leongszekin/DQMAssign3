# %% [markdown]
# # Assignment 5

# %%
import pandas as pd

# Load your original heart attack dataset
heart_attack_df = pd.read_csv("heart_attack_risk_dataset.csv")

# Load the new obesity dataset
obesity_df = pd.read_csv("Obesity prediction.csv")

# Merge the datasets on Age and Gender
merged_df = heart_attack_df.merge(obesity_df, on=["Age", "Gender"], how="inner")  

# Display the first few rows of the merged dataset
merged_df.head(20)
# Out:
# C:\Users\liang\AppData\Local\Temp\ipykernel_8648\3829393384.py:10: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   merged_df = heart_attack_df.merge(obesity_df, on=["Age", "Gender"], how="inner")
#     Age  Gender  Smoking  Alcohol_Consumption Physical_Activity_Level    BMI  \
# 0    32    Male        0                    0                Moderate  22.75
# 1    38  Female        1                    0                Moderate  19.82
# 2    38  Female        1                    0                Moderate  19.82
# 3    38  Female        1                    0                Moderate  19.82
# 4    38  Female        1                    0                Moderate  19.82
# 5    41    Male        0                    1                Moderate  36.11
# 6    41    Male        0                    1                Moderate  36.11
# 7    41    Male        0                    1                Moderate  36.11
# ...
